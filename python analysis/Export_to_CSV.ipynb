# %%
# Morning health check — yesterday's calls per client

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector
from sqlalchemy import create_engine


conn = mysql.connector.connect(
    host="localhost", user="root",
    password="Abhi@1445", database="sirrus_tcg"
)
engine = create_engine("mysql+pymysql://root:Abhi%401445@localhost/sirrus_tcg")

# Helper: run any SQL and get a DataFrame instantly

def sql(query):
    return pd.read_sql(query, engine)

print("Connected ✅")
# Out:
# Connected ✅

# %%
tables = ['clients', 'calls', 'user_logins', 'feature_logs', 'tickets']

for table in tables:
    df = sql(f"SELECT * FROM {table}")
    print(f"\n{table} columns: {df.columns.tolist()}")
    df.to_csv(f"{table}.csv", index=False)
    print(f"✅ {table}.csv — {len(df)} rows exported")
# Out:
# clients columns: ['client_id', 'company_name', 'city', 'account_manager', 'onboarding_date', 'subscription_plan', 'deal_value', 'status']
# ✅ clients.csv — 12 rows exported
#
# calls columns: ['call_id', 'client_id', 'lead_id', 'sales_exec', 'call_date', 'call_duration_sec', 'call_status', 'ai_summary_status', 'pair_score']
# ✅ calls.csv — 1200 rows exported
#
# user_logins columns: ['login_id', 'client_id', 'user_id', 'login_time']
# ✅ user_logins.csv — 2000 rows exported
#
# feature_logs columns: ['log_id', 'client_id', 'user_id', 'module', 'feature_name', 'used_at']
# ✅ feature_logs.csv — 3000 rows exported
#
# tickets columns: ['ticket_id', 'client_id', 'customer_id', 'category', 'status', 'created_at', 'resolved_at']
# ✅ tickets.csv — 220 rows exported
